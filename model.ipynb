# %%
import os
import datetime
import numpy as np
import pandas as pd
import data_getters
from entities import Player, Game
import model
import boxscores
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.formula.api as sm

# %%
data_getters.download_gamelog_jsons(2014,'boxscores_advanced/2014',boxtype='advanced',start_game=210, end_game=1230)
# Out:
# 210
# Downloaded until game 209

# %%
# LOADS DATA TO MEMORY AND WRITES TO CSV

# TODO: CHANGE DAY
latest_day = datetime.date(2014,11,25)
dk = 'DraftKings'
fd = 'FanDuel'

player_data, game_data = boxscores.load_jsons_to_memory('boxscores_advanced/2014', latest_day)
players = [p.get_name() for p in player_data]

vegas_lines = data_getters.get_vegas_lines('vegas_lines/' + str(latest_day+datetime.timedelta(days=1)) + '_lines.csv', site='covers')

model.write_predictions(player_data, 'ema', 'model_predictions/model_predictions_' + dk + '_' + str(latest_day) + '.csv', dk)
model.write_predictions(player_data, 'ema', 'model_predictions/model_predictions_' + fd + '_' + str(latest_day) + '.csv', fd)

model.write_predictions(player_data, 'possessions', 'model_predictions/pos_model_predictions_' + dk + '_' + str(latest_day) + '.csv', dk)
# Out:
# True

# %%
# EXAMPLE USAGE
lookup = 'Jimmy Butler'
p = player_data[players.index(lookup)]
p_info = p.get_info()
p_adv_info = p.get_adv_info()

#for key in p_info:
#    print key + ": " + str(p_info[key])

#for key in p_adv_info:
#    print key + ": " + str(p_adv_info[key])
    
print "\npredictions"

for s in ['PTS', 'FG3M', 'REB', 'AST', 'STL', 'BLK', 'TO']:
    print s + ": " + str(p.predict(s))

print "expected FP (DK): " + str(p.calculate_fp(game_number='predict', site="DraftKings"))

p.possessions_model(101.)
# Out:
# predictions
# PTS: 23.9365194334
# FG3M: 0.522756452485
# REB: 6.02299214493
# AST: 2.22877168751
# STL: 1.8383716752
# BLK: 0.125631861182
# TO: 1.93930103777
# expected FP (DK): 38.0281519259
# {'predicted_fp': 40.039995009686677, 'predicted_sd': 8.5259519332641336}

# %%
# CALCULATES FP FOR A GIVEN TEAM

def print_summary(team, game_number):
    score = []
    var = []
    for t in team:
        p = player_data[players.index(t)]
        score.append(p.calculate_fp(game_number))
        var.append(p.calculate_fp_variance(scaled=False))
        print t + ": " + "%.2f" % score[-1] + "\t\tStd: " + "%.2f" % np.sqrt(var[-1]) + "\t ScaledStd: " + "%.2f" % (np.sqrt(var[-1])/score[-1])
    
    print "Total: " + str(sum([x for x in score if x != None]))
    print "Std of lineup: " + str(np.sqrt(sum(var)))

team = ['D.J. Augustin',
'Jimmy Butler',
'Luol Deng',
'Pau Gasol',
'DeMarcus Cousins',
'Ben McLemore',
'Wilson Chandler',
'Marreese Speights']

print_summary(team, game_number=-1)
print
# Out:
# D.J. Augustin: 24.00		Std: 6.76	 ScaledStd: 0.28
# Jimmy Butler: 45.75		Std: 7.89	 ScaledStd: 0.17
# Luol Deng: 23.75		Std: 9.15	 ScaledStd: 0.39
# Pau Gasol: 42.75		Std: 7.35	 ScaledStd: 0.17
# DeMarcus Cousins: 51.50		Std: 10.46	 ScaledStd: 0.20
# Ben McLemore: 17.00		Std: 9.17	 ScaledStd: 0.54
# Wilson Chandler: 23.25		Std: 7.41	 ScaledStd: 0.32
# Marreese Speights: 15.25		Std: 10.97	 ScaledStd: 0.72
# Total: 243.25
# Std of lineup: 24.7838799575

# %%
### REGRESSION: Players' fantasy points vs pace of the game. Filtered by players who play more than X minutes.
## results: ??

gids = [g.get_game_id() for g in game_data]
pace = []
player_fp = []
for p in player_data:
    p_info = p.get_info()
    index = 0
    for gid in p_info['GAME_ID']:
        g = game_data[gids.index(gid)]
        temp = p.calculate_fp(game_number=index,site='DraftKings')
        if temp is not None:
            # minutes filter
            if float(p_info['MIN'][index].split(':')[0]) > 20:
                pace.append(g.home_info['PACE']) #WLOG use home_info, pace should be the same for both teams
                player_fp.append(temp)
        index += 1
        
df = pd.DataFrame(np.array([pace, player_fp]).T, columns=['pace', 'fp'])
df['const'] = np.ones((len(df), ))
reg = sm.OLS(df.fp, df[['pace', 'const']]).fit()
print reg.summary()

plt.figure()
plt.plot(df.pace, df.fp, '.', alpha=0.5)
xval = np.linspace(80,110,10)
plt.plot(xval, reg.params['const']+reg.params['pace']*xval,'-')
plt.xlabel('pace')
plt.ylabel('fantasy points')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     fp   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     5.014
# Date:                Sat, 22 Nov 2014   Prob (F-statistic):             0.0252
# Time:                        13:45:24   Log-Likelihood:                -8520.2
# No. Observations:                2208   AIC:                         1.704e+04
# Df Residuals:                    2206   BIC:                         1.706e+04
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# pace           0.1197      0.053      2.239      0.025         0.015     0.224
# const         15.5885      5.125      3.041      0.002         5.538    25.639
# ==============================================================================
# Omnibus:                       88.025   Durbin-Watson:                   1.297
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.003
# Skew:                           0.515   Prob(JB):                     5.24e-22
# Kurtosis:                       3.070   Cond. No.                     2.01e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
### REGRESSION: Players' fantasy points vs opponent's def ratings. Filtered by players who play more than X minutes.
## results: not promising; check accuracy of data?

#for g in game_data:
#    print g
#def_ratings, off_ratings = data_getters.get_def_ratings(2015) # may take a bit to hit all the teams
def_ratings['CHA'] = def_ratings['CHO'] # note CHO = CHA
def_ratings['PHX'] = def_ratings['PHO'] # note PHO = PHX
def_ratings['BKN'] = def_ratings['BRK']
#print def_ratings


# regress a player's fantasy points vs opponent's def rating
gids = [g.get_game_id() for g in game_data]
opp_def_rating = []
player_fp = []
for p in player_data:
    p_info = p.get_info()
    index = 0
    for gid in p_info['GAME_ID']:
        g = game_data[gids.index(gid)]
        # check for which team the player is on, then get the other team's defensive rating
        if p_info['TEAM_ID'][index] == g.get_home_id():
            opp_abb = g.get_away_abb()
        elif p_info['TEAM_ID'][index] == g.get_away_id():
            opp_abb = g.get_home_abb()
        else:
            print "what"
        temp = p.calculate_fp(game_number=index,site='DraftKings')
        if temp is not None:
            # minutes filter
            if float(p_info['MIN'][index].split(':')[0]) > 20:
                opp_def_rating.append(def_ratings[opp_abb])
                player_fp.append(temp)
        index += 1

        
df = pd.DataFrame(np.array([opp_def_rating, player_fp]).T, columns=['opp_def_rating', 'fp'])
df['const'] = np.ones((len(df), ))
reg = sm.OLS(df.fp, df[['opp_def_rating', 'const']]).fit()
print reg.summary()

plt.figure()
plt.plot(df.opp_def_rating, df.fp, '.', alpha=0.5)
xval = np.linspace(95,120,10)
plt.plot(xval, reg.params['const']+reg.params['opp_def_rating']*xval,'-')
plt.xlabel('opponent def rating')
plt.ylabel('fantasy points')
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     fp   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     14.69
# Date:                Sat, 22 Nov 2014   Prob (F-statistic):           0.000130
# Time:                        13:50:19   Log-Likelihood:                -8515.4
# No. Observations:                2208   AIC:                         1.703e+04
# Df Residuals:                    2206   BIC:                         1.705e+04
# Df Model:                           1
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# opp_def_rating     0.1979      0.052      3.833      0.000         0.097     0.299
# const              6.0603      5.483      1.105      0.269        -4.691    16.812
# ==============================================================================
# Omnibus:                       90.884   Durbin-Watson:                   1.291
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.459
# Skew:                           0.523   Prob(JB):                     9.30e-23
# Kurtosis:                       3.100   Cond. No.                     2.39e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
