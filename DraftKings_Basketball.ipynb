# %%
# draftkings basketball analyzer

# imports
import csv
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import math
import operator
# %matplotlib inline

# class
class Player:
    # name (String): player name
    # position (String): player position
    # salary (float): draftkings salary
    # game (String): game they are playing in
    # DKppg (float): draftkings fantasy points per game
    def __init__(self, name, position, salary, game, DKppg):
        self.name = name
        self.position = position
        self.salary = float(salary)
        self.game = game
        self.DKppg = float(DKppg)
    
    # predict the given stat:
    # [PTS, 3PTM, REB, AST, STL, BLK, TO]
    def predict(self, stat):
        """ TODO """
        return 0
    
    def __repr__(self):
        return self.name + ', ' + str(self.salary)
    
    def __str__(self):
        return self.name + ', ' + str(self.salary)

# %%
# calculates expected fantasy points
# DK Formula:
#   Point = +1 PT
#   Made 3pt. shot = +0.5 PTs
#   Rebound = +1.25 PTs
#   Assist = +1.5 PTs
#   Steal = +2 PTs
#   Block = +2 PTs
#   Turnover = -0.5 PTs
#   Double-Double = +1.5PTs (MAX 1 PER PLAYER: Points, Rebounds, Assists, Blocks, Steals)
#   Triple-Double = +3PTs (MAX 1 PER PLAYER: Points, Rebounds, Assists, Blocks, Steals)
def expected_fp(player):
    fp = 0
    doubled = 0
    weights = {'PTS': 1.0, '3PTM': 0.5, 'REB': 1.25, 'AST': 1.5, 'STL': 2.0, 'BLK': 2.0, 'TO': -0.5}
    for s, w in weights:
        v = player.predict(s)
        fp += v * w
        if s in ['PTS', 'REB', 'AST', 'BLK', 'STL']:
            if v >= 10.0:
                doubled += 1
    if doubled == 2:
        fp += 1.5
    elif doubled >= 3:
        fp += 4.5 # assume that you get both DD and TD bonus
    return fp

# optimizes expected FP based on total salary and positional constraints
# players: list of Player objects
# total_salary: a float representing total salary that can be spent
# assumes roster positions=['PG','SG','SF','PF','C','G','F','UTIL']
# returns a subset of players which maximizes expected FP given salary constraints

# maximize sum of p.DKppg under the constraints:
#   sum of p.salary <= total_salary
#   1 <= n(PG) <= 2
#   1 <= n(SG) <= 2
#   1 <= n(SF) <= 2
#   1 <= n(PF) <= 2
#   1 <= n(C) <= 2
#   4 <= n(PG) + n(SG) + n(C) <= 5
#   4 <= n(SF) + n(PF) + n(C) <= 5
#   n(PG) + n(SG) + n(SF) + n(PF) + n(C) = 8

def objective(x, players):
    return -x.dot(np.array([p.DKppg for p in players]))

def objective2(x, players, total_salary):
    s = -x.dot(np.array([p.DKppg for p in players]))
    
    pg = np.array([1 if p.position == 'PG' else 0 for p in players])
    sg = np.array([1 if p.position == 'SG' else 0 for p in players])
    sf = np.array([1 if p.position == 'SF' else 0 for p in players])
    pf = np.array([1 if p.position == 'PF' else 0 for p in players])
    c = np.array([1 if p.position == 'C' else 0 for p in players])
    
    n_pg = x.dot(pg)
    n_sg = x.dot(sg)
    n_sf = x.dot(sf)
    n_pf = x.dot(pf)
    n_c = x.dot(c)
    
    penalty = -100000

    if sum(x) != 8:
        return penalty
    if x.dot(np.array([p.salary for p in players])) > total_salary:
        return penalty
    if n_pg < 1 or n_pg > 2:
        return penalty
    if n_sg < 1 or n_sg > 2:
        return penalty
    if n_sf < 1 or n_sf > 2:
        return penalty
    if n_pf < 1 or n_pf > 2:
        return penalty
    if n_c < 1 or n_c > 2:
        return penalty
    if n_pg + n_sg + n_c < 4 or n_pg + n_sg + n_c > 5:
        return penalty
    if n_sf + n_pf + n_c < 4 or n_sf + n_pf + n_c > 5:
        return penalty
    
    return s
    
def optimize(players, total_salary=50000):
    """TODO"""
    ind = np.zeros(len(players))
    ind[0] = 1
    ind[1] = 1
    #pg = np.array([1 if p.position == 'PG' else 0 for p in players])
    #sg = np.array([1 if p.position == 'SG' else 0 for p in players])
    #sf = np.array([1 if p.position == 'SF' else 0 for p in players])
    #pf = np.array([1 if p.position == 'PF' else 0 for p in players])
    #c = np.array([1 if p.position == 'C' else 0 for p in players])
    
    #print minimize(objective2, ind, args=(players,total_salary))

    return

# imports a file from draftkings containing salary info
# returns a list of Player objects
def import_draftkings_salary(filename):
    players = []
    with open(filename, 'rb') as f:
        csvreader = csv.reader(f, delimiter=',')
        col_names = csvreader.next()
        for row in csvreader:
            p = Player(row[1], row[0], float(row[2]), row[3], float(row[4]))
            players.append(p)
    return players

fn = 'draftkings_data/DKSalaries_11022014.csv'
players = import_draftkings_salary(fn)
#optimize(players)

# %%
def get_residuals(players, show_plot=True):
    fppg = []
    cost = []
    
    for p in players:
        if p.DKppg != 0:
            fppg.append(p.DKppg)
            cost.append(p.salary)
    
    fit = np.polyfit(cost, fppg, 1)
    #print fit
    print fit[0]*7500+fit[1]
    
    resids = {}
    for p in players:
        yhat = fit[0]*p.salary+fit[1]
        resid = p.DKppg - yhat
        resids[p.name] = resid
        
    if show_plot:
        x = np.linspace(3000,11000,10000)
        plt.figure()
        plt.plot(cost, fppg, 'x')
        plt.plot(x, fit[0]*x+fit[1])
        plt.show()
    
    return fit, resids


fit, resids = get_residuals(players, show_plot=False)
sorted_resid = sorted(resids.items(), key=operator.itemgetter(1), reverse=True)
for s in sorted_resid:
    print s

def evaluate_team(fit, players, team):
    player_dict = {}
    for p in players:
        player_dict[p.name] = p
    total = 0
    total_salary = 0
    for p in team:
        pl = player_dict[p]
        proj = fit[0]*pl.salary+fit[1]
        total += proj
        total_salary += pl.salary
        print pl.name + ", " + str(proj)
    print total_salary
    return total

#print evaluate_team(fit, players,
#              ['Jeremy Lin', 'Kyle Korver', 'Mike Dunleavy', 'Anthony Davis', 
#                    'Nikola Vucevic', 'Mo Williams', 'Michael Kidd-Gilchrist', 'Chris Bosh'])
# Out:
# 34.3813659419
# ('Shane Larkin', 12.276329981171621)
# ('Shawne Williams', 11.731030434159337)
# ('Chris Kaman', 10.92197052475688)
# ('Klay Thompson', 10.920813786268425)
# ('Chris Bosh', 10.666795326426652)
# ('Darren Collison', 10.604873695670875)
# ('Michael Kidd-Gilchrist', 10.108892155512649)
# ('Quincy Acy', 8.7900903435617934)
# ('Gary Neal', 8.217270071769164)
# ('Stephen Curry', 7.7808966853897914)
# ('Norris Cole', 7.2723115213298506)
# ('Rudy Gay', 6.9936340580610477)
# ('Steve Blake', 6.6582101623667072)
# ('Harrison Barnes', 6.0676110683421349)
# ('Jamal Crawford', 5.9317124273052784)
# ('Pablo Prigioni', 5.6513299811716209)
# ('DeMar DeRozan', 5.2573944204512202)
# ('Shabazz Napier', 5.1582101623667072)
# ('Mario Chalmers', 3.9907723367077352)
# ('Iman Shumpert', 3.8038507059519659)
# ('Cole Aldrich', 3.6513299811716209)
# ('Patrick Patterson', 3.4426110683421349)
# ('Brian Roberts', 2.7763299811716209)
# ('Terrence Ross', 2.6541917025249369)
# ('Jonas Valanciunas', 2.5704727896954473)
# ('Leandro Barbosa', 2.5263299811716209)
# ('Wesley Matthews', 2.4523529708905336)
# ('Greivis Vasquez', 2.4288507059519659)
# ('Jason Smith', 2.4013299811716209)
# ("Amar'e Stoudemire", 2.3313714307323075)
# ('Omri Casspi', 2.2763299811716209)
# ('Marreese Speights', 2.1719705247568797)
# ('Carl Landry', 2.1513299811716209)
# ('Chris Andersen', 1.9741502529642503)
# ('Amir Johnson', 1.8342331520856199)
# ('Robin Lopez', 1.8135926085003611)
# ('Samuel Dalembert', 1.7763299811716209)
# ('James Johnson', 1.7241502529642503)
# ('Andrew Bogut', 1.1610718837200196)
# ('Lou Williams', 1.1513299811716209)
# ('Reggie Evans', 0.40132998117162089)
# ('Andre Iguodala', 0.33825161192739372)
# ('Marvin Williams', 0.27919170252493686)
# ('Kyle Lowry', 0.27115478284139272)
# ('Tyler Hansbrough', 0.026329981171620886)
# ('Draymond Green', -0.002347482097182052)
# ('J.J. Redick', -0.057388931657865072)
# ('Jason Thompson', -0.58490965643820658)
# ('James Ennis', -0.72367001882837911)
# ('Festus Ezeli', -0.84867001882837911)
# ('Spencer Hawes', -1.3733290222554082)
# ('J.R. Smith', -1.4048682068775236)
# ('Matt Barnes', -1.4323889316578651)
# ('Luol Deng', -2.1864073914996389)
# ('Dwyane Wade', -2.5132461231340386)
# ('Al Jefferson', -2.5172645829758125)
# ('Nicolas Batum', -2.6451263043291249)
# ('Gerald Henderson', -2.7099096564382066)
# ('Derrick Williams', -2.7236700188283791)
# ('Blake Griffin', -2.7397438581954674)
# ('Jordan Farmar', -2.8486700188283791)
# ('Hedo Turkoglu', -2.9736700188283791)
# ('Nik Stauskas', -3.3417898376332928)
# ('DeAndre Jordan', -3.4610663949266645)
# ('Dorell Wright', -3.7236700188283791)
# ('Chris Paul', -3.944444311183176)
# ('Chris Douglas-Roberts', -4.3486700188283791)
# ('Allen Crabbe', -4.4736700188283791)
# ('Cody Zeller', -4.6095686598652357)
# ('LaMarcus Aldridge', -4.8332046735733485)
# ('Tim Hardaway Jr.', -5.0917898376332928)
# ('Jason Maxiell', -5.0986700188283791)
# ('Justin Hamilton', -5.2236700188283791)
# ('Travis Wear', -5.2236700188283791)
# ('Kemba Walker', -5.3607253983536935)
# ('Joel Freeland', -5.5986700188283791)
# ('Lance Stephenson', -5.7701263043291249)
# ('Ben McLemore', -5.8142691128529513)
# ('Thomas Robinson', -5.9736700188283791)
# ('Ognjen Kuzmic', -5.9736700188283791)
# ('Ramon Sessions', -6.2236700188283791)
# ('Ryan Hollins', -6.5986700188283791)
# ('Damian Lillard', -6.6244857607438661)
# ('Shaun Livingston', -6.7099096564382066)
# ('C.J. McCollum', -6.9736700188283791)
# ('Justin Holiday', -7.4736700188283791)
# ('Cleanthony Early', -7.7236700188283791)
# ('DeMarcus Cousins', -8.6353844017807262)
# ('Jeffery Taylor', -9.2236700188283791)
# ('Chuck Hayes', -9.2236700188283791)
# ('Jannero Pargo', -9.2236700188283791)
# ('Ray McCallum', -9.2236700188283791)
# ('Reggie Bullock', -9.2236700188283791)
# ('Meyers Leonard', -9.2236700188283791)
# ('Will Barton', -9.2236700188283791)
# ('Shannon Brown', -9.2236700188283791)
# ('Ekpe Udoh', -9.2236700188283791)
# ('Andre Dawkins', -9.2236700188283791)
# ('Landry Fields', -9.2236700188283791)
# ('Nemanja Nedovic', -9.2236700188283791)
# ('Danny Granger', -9.2236700188283791)
# ('C.J. Wilcox', -9.2236700188283791)
# ('Jared Cunningham', -9.2236700188283791)
# ('P.J. Hairston', -9.2236700188283791)
# ('Brandon Rush', -9.2236700188283791)
# ('Bruno Caboclo', -9.2236700188283791)
# ('Lucas Nogueira', -9.2236700188283791)
# ('Noah Vonleh', -9.2236700188283791)
# ('Bismack Biyombo', -9.2236700188283791)
# ('Victor Claver', -9.2236700188283791)
# ('Udonis Haslem', -9.2236700188283791)
# ('Eric Moreland', -9.2236700188283791)
# ('Greg Stiemsma', -9.2236700188283791)
# ('Glen Davis', -9.2236700188283791)
# ('Carmelo Anthony', -12.267264582975812)
# ('Andrea Bargnani', -15.932388931657865)
# ('Josh McRoberts', -18.009227663292265)
# ('Jose Calderon', -23.759227663292265)
# ('David Lee', -32.145126304329125)
